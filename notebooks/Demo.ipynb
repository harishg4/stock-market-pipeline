# %%
# %python
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()
w.secrets.put_secret("stock-api", "api-key", string_value="ZVG3CQYLUO8Q83XQ")

# %%
# Retrieve your API key securely
api_key = dbutils.secrets.get(scope="stock-api", key="api-key")

# Verify it's retrieved (won't display the actual key for security)
print("API key retrieved successfully!")
print(f"Key length: {len(api_key)} characters")
